# %% [markdown]
# <a href="https://colab.research.google.com/github/twinkleSojeong/StockAnalysisInPython/blob/master/ESG_ETF_ranking_example1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 210926 자료

# %%
import pandas as pd

# %%
merge1 = pd.read_csv('15H.csv')
merge1
# Out:
#               상품명      상품코드   종목코드.1  ...   사회  지배구조  MSCI
# 0    arirang_good  278420.0   5930.0  ...   A+     C     A
# 1    arirang_good  278420.0  12750.0  ...    A    B+    BB
# 2    arirang_good  278420.0  35420.0  ...   B+    A+   AAA
# 3    arirang_good  278420.0  97950.0  ...   A+     A     A
# 4    arirang_good  278420.0    810.0  ...   A+     A   NaN
# ..            ...       ...      ...  ...  ...   ...   ...
# 491           NaN       NaN      NaN  ...  NaN   NaN   NaN
# 492           NaN       NaN      NaN  ...  NaN   NaN   NaN
# 493           NaN       NaN      NaN  ...  NaN   NaN   NaN
# 494           NaN       NaN      NaN  ...  NaN   NaN   NaN
# 495           NaN       NaN      NaN  ...  NaN   NaN   NaN
#
# [496 rows x 13 columns]

# %%
merge2 = pd.read_csv('16H.csv')
merge2
# Out:
#                  상품명    상품코드  종목코드.1    구성종목명  ...   환경   사회  지배구조  MSCI
# 0       arirang_good  278420    5930     삼성전자  ...    A   A+     C     A
# 1       arirang_good  278420   12750      에스원  ...    B    A    B+    BB
# 2       arirang_good  278420   35420    NAVER  ...   B+   B+    A+   AAA
# 3       arirang_good  278420   97950   CJ제일제당  ...    A   A+     A     A
# 4       arirang_good  278420     810     삼성화재  ...   A+   A+     A   NaN
# ..               ...     ...     ...      ...  ...  ...  ...   ...   ...
# 485  tiger_universal  289250   42660   대우조선해양  ...   B+    B     A   CCC
# 486  tiger_universal  289250    5387   현대차2우B  ...  NaN  NaN   NaN   NaN
# 487  tiger_universal  289250   51915    LG화학우  ...    C    A    B+   NaN
# 488  tiger_universal  289250   51905  LG생활건강우  ...    A   A+     A   NaN
# 489  tiger_universal  289250    5385     현대차우  ...  NaN  NaN   NaN   NaN
#
# [490 rows x 13 columns]

# %%
merge2.to_csv('merge.csv')

# %%
merge3 = merge2.dropna(axis=0)
merge3
# Out:
#                  상품명    상품코드  종목코드.1   구성종목명  주식수(계약수)  ...  ESG등급  환경  사회 지배구조 MSCI
# 0       arirang_good  278420    5930    삼성전자       134  ...      B   A  A+    C    A
# 1       arirang_good  278420   12750     에스원       244  ...     B+   B   A   B+   BB
# 2       arirang_good  278420   35420   NAVER        44  ...      A  B+  B+   A+  AAA
# 3       arirang_good  278420   97950  CJ제일제당        48  ...      A   A  A+    A    A
# 8       arirang_good  278420    5490   POSCO        18  ...      A   A   B   A+  BBB
# ..               ...     ...     ...     ...       ...  ...    ...  ..  ..  ...  ...
# 391           kbstar  290130   10950   두산중공업       264  ...      A   A  A+   B+    B
# 394           kbstar  290130   36460    아모레G        34  ...      A   A  A+    A   AA
# 395           kbstar  290130  204320     녹십자         7  ...     B+   B   A    B    B
# 484  tiger_universal  289250   78930      GS        17  ...     B+   C   A    A  BBB
# ...

# %%
merge3.to_csv('16.csv')

# %% [markdown]
# 저번시간에 진행한 내용들

# %%
import pandas as pd

# %%
esg = pd.read_csv('ESG.csv')

# %%
etf = pd.read_csv('ESG_ETF.csv')

# %%
con = pd.merge(etf,esg)
con
# Out:
#                   상품명    상품코드   종목코드.1   구성종목명  ...  MSCI   NO   종목코드     종목명
# 0        arirang_good  278420   5930.0    삼성전자  ...     A    1   5930    삼성전자
# 1        arirang_good  278420  12750.0     에스원  ...    BB  101  12750     에스원
# 2        arirang_good  278420  35420.0   NAVER  ...   AAA    3  35420   NAVER
# 3        arirang_good  278420  97950.0  CJ제일제당  ...     A   20  51900  LG생활건강
# 4        arirang_good  278420  97950.0  CJ제일제당  ...     A   55  97950  CJ제일제당
# ...               ...     ...      ...     ...  ...   ...  ...    ...     ...
# 4446            focus  285690   1740.0  SK네트웍스  ...   NaN  162   1740  SK네트웍스
# 4447            focus  285690   1740.0  SK네트웍스  ...   NaN  189  71840  롯데하이마트
# 4448            focus  285690  71840.0  롯데하이마트  ...   NaN  162   1740  SK네트웍스
# 4449            focus  285690  71840.0  롯데하이마트  ...   NaN  189  71840  롯데하이마트
# 4450  tiger_universal  289250  78930.0      GS  ...   BBB   85  78930      GS
#
# [4451 rows x 16 columns]

# %%
con.to_csv('merge.csv')

# %%
con1 = pd.merge(etf, esg, on="종목코드.1")
con1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-871709cdba4b> in <module>()
# ----> 1 con1 = pd.merge(etf, esg, on="종목코드.1")
#       2 con1
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...

# %% [markdown]
# 9월25일 코드

# %%
df1 = pd.read_csv('ARIRANG_GOOD.csv')

# %%
df2 = pd.read_csv('ESG.csv')

# %%
print(df1)
print(df2)
# Out:
#              상품명    상품코드    종목코드  ...      평가금액      시가총액  시가총액 구성비중
# 0   arirang_good  278420    4690  ...  20761200  21133500       4.18
# 1   arirang_good  278420   12750  ...  20788800  20715600       4.09
# 2   arirang_good  278420   18670  ...  20751500  20691000       4.09
# 3   arirang_good  278420   97950  ...  20616000  20688000       4.09
# 4   arirang_good  278420   35420  ...  17688000  17732000       3.50
# 5   arirang_good  278420  213500  ...  17114600  17217700       3.40
# 6   arirang_good  278420     810  ...  15436000  15470000       3.06
# 7   arirang_good  278420  298050  ...  14763000  15390000       3.04
# 8   arirang_good  278420    4370  ...  15529000  15370000       3.04
# 9   arirang_good  278420    4360  ...  15221250  15276600       3.02
# 10  arirang_good  278420   14680  ...  14070000  14007000       2.77
# 11  arirang_good  278420   12630  ...  13467300  13350700       2.64
# 12  arirang_good  278420   30200  ...  12512500  12531750       2.48
# ...

# %%
merge_inner = pd.merge(df1,df2)

# %%
merge_inner
# Out:
#              상품명    상품코드    종목코드    구성종목명  주식수(계약수)  ...  ESG등급   환경   사회  지배구조 MSCI
# 0   arirang_good  278420   12750      에스원       244  ...     B+    B    A    B+   BB
# 1   arirang_good  278420   97950   CJ제일제당        48  ...      A    A   A+     A    A
# 2   arirang_good  278420   35420    NAVER        44  ...      A   B+   B+    A+  AAA
# 3   arirang_good  278420     810     삼성화재        68  ...      A   A+   A+     A  NaN
# 4   arirang_good  278420  298050   효성첨단소재        19  ...     A+   A+   A+     A  NaN
# 5   arirang_good  278420    4370       농심        53  ...     B+   B+    A     B  NaN
# 6   arirang_good  278420   14680    한솔케미칼        42  ...     B+    B   B+    B+  NaN
# 7   arirang_good  278420   30200       KT       385  ...     A+    A    A    A+  NaN
# 8   arirang_good  278420    7070    GS리테일       354  ...      B    C    B    B+  NaN
# 9   arirang_good  278420   33780     KT&G       145  ...    NaN  NaN  NaN   NaN   AA
# ...

# %%
import numpy as np
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
trace1 = go.Scatter(x=merge_inner['ESG등급'], y=merge_inner['시가총액'], mode='markers')
data = [trace1]
pyo.iplot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-02c09433f207> in <module>()
# ----> 1 trace1 = go.Scatter(x=merge_inner['ESG등급'], y=merge_inner['시가총액'], mode='markers')
#       2 data = [trace1]
#       3 pyo.iplot(data)
#
# NameError: name 'go' is not defined

# %%
#경민님 작성
# list=merge_inner['ESG등급']
# sorted(list, key=lambda g: (g[0], '+ -'.index((g+' ')[1])))
# trace1 = go.Scatter(x=merge_inner['ESG등급'], y=merge_inner['시가총액'], mode='markers')
# data = [trace1]
# pyo.iplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f4f2fb002718> in <module>()
#       1 #경민님 작성
#       2 list=merge_inner['ESG등급']
# ----> 3 sorted(list, key=lambda g: (g[0], '+ -'.index((g+' ')[1])))
#       4 # trace1 = go.Scatter(x=merge_inner['ESG등급'], y=merge_inner['시가총액'], mode='markers')
#       5 # data = [trace1]
#
# <ipython-input-17-f4f2fb002718> in <lambda>(g)
#       1 #경민님 작성
#       2 list=merge_inner['ESG등급']
# ----> 3 sorted(list, key=lambda g: (g[0], '+ -'.index((g+' ')[1])))
#       4 # trace1 = go.Scatter(x=merge_inner['ESG등급'], y=merge_inner['시가총액'], mode='markers')
#       5 # data = [trace1]
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# ESG 등급 순서 정렬

# %%
import plotly as pt
df = pt.data.merge_inner()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-fb14089243ce> in <module>()
#       1 import plotly as pt
# ----> 2 df = pt.data.merge_inner()
#       3 df
#
# AttributeError: module 'plotly.data' has no attribute 'merge_inner'

# %%
fig = px.scatter(merge_inner, x="ESG등급", y="시가총액")

fig.update_xaxes(categoryorder='array', categoryarray= ['B','B+','A','A+'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b351e75-0b9f-48ad-8329-ed51e23eadda" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b351e75-0b9f-48ad-8329-ed51e23eadda")) {
#                     Plotly.newPlot(
#                         '0b351e75-0b9f-48ad-8329-ed51e23eadda',
# ...

# %%
fig = px.box(merge_inner, x="ESG등급", y="시가총액")

fig.update_xaxes(categoryorder='array', categoryarray= ['B','B+','A','A+'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="018dffc3-5608-4b57-907f-226257e62a8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("018dffc3-5608-4b57-907f-226257e62a8b")) {
#                     Plotly.newPlot(
#                         '018dffc3-5608-4b57-907f-226257e62a8b',
# ...

# %%
fig.update_layout(barmode='stack')
fig.update_xaxes(categoryorder='array', categoryarray= ['d','a','c','b'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="15a22d3f-c6cd-4c4c-8baa-616fb5a510d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("15a22d3f-c6cd-4c4c-8baa-616fb5a510d0")) {
#                     Plotly.newPlot(
#                         '15a22d3f-c6cd-4c4c-8baa-616fb5a510d0',
# ...

# %%
df2
# Out:
#       NO    종목코드       종목명 ESG등급  환경  사회 지배구조 MSCI
# 0      1    5930      삼성전자     B   A  A+    C    A
# 1      2     660    SK하이닉스     A   A  A+    A  BBB
# 2      3   35420     NAVER     A  B+  B+   A+  AAA
# 3      4  207940  삼성바이오로직스    B+   B   A   B+    B
# 4      5   35720       카카오    B+   C  A+    A  BBB
# ..   ...     ...       ...   ...  ..  ..  ...  ...
# 195  196    1680        대상     B   B  B+    B  NaN
# 196  197    2350     넥센타이어    B+  B+  B+    B  NaN
# 197  198  192400     쿠쿠홀딩스     B   D   B   B+  NaN
# 198  199    3230      삼양식품     B   B   B    B  NaN
# 199  200    7570      일양약품     B   D   B   B+  NaN
#
# [200 rows x 8 columns]

# %%
import plotly.express as px

# %%
fig = px.scatter(df2, x="ESG등급", y="MSCI",
                 size='시가총액', hover_data=['종목명'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b8343ddac16f> in <module>()
#       1 fig = px.scatter(df2, x="ESG등급", y="MSCI",
# ----> 2                  size='시가총액', hover_data=['종목명'])
#       3 fig.show()
#
# /usr/local/lib/python3.7/dist-packages/plotly/express/_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_color_override, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      53     mark in 2D space.
#      54     """
# ...

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(df2, y="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0f02a48d-877e-4dac-99e9-2eefd34e6a22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f02a48d-877e-4dac-99e9-2eefd34e6a22")) {
#                     Plotly.newPlot(
#                         '0f02a48d-877e-4dac-99e9-2eefd34e6a22',
# ...

# %%
df3 = pd.read_excel('esg_etf.xlsx')

# %%
df3
# Out:
#                  상품명    상품코드      종목코드  ...      평가금액      시가총액 시가총액 구성비중
# 0       arirang_good  278420    4690.0  ...  20761200  21133500      4.18
# 1       arirang_good  278420   12750.0  ...  20788800  20715600      4.09
# 2       arirang_good  278420   18670.0  ...  20751500  20691000      4.09
# 3       arirang_good  278420   97950.0  ...  20616000  20688000      4.09
# 4       arirang_good  278420   35420.0  ...  17688000  17732000      3.50
# ..               ...     ...       ...  ...       ...       ...       ...
# 487  tiger_universal  289250   51905.0  ...   673000    661000       0.18
# 488  tiger_universal  289250    5385.0  ...   410000    398400       0.11
# 489  tiger_universal  289250   42660.0  ...   205450    201600       0.05
# 490         kodex200  337160  180640.0  ...   4247800   4221000      0.29
# 491         kodex200  337160       NaN  ...         -   4364386      0.30
#
# [492 rows x 8 columns]

# %%
df4 = pd.read_csv('ESG.csv')

# %%
esg_etf = pd.merge(df3,df4)

# %%
esg_etf
# Out:
#                  상품명    상품코드      종목코드       구성종목명  ...   환경   사회 지배구조  MSCI
# 0       arirang_good  278420   12750.0         에스원  ...    B    A   B+    BB
# 1       arirang_good  278420   97950.0      CJ제일제당  ...    A   A+    A     A
# 2       arirang_good  278420   35420.0       NAVER  ...   B+   B+   A+   AAA
# 3       arirang_good  278420     810.0        삼성화재  ...   A+   A+    A   NaN
# 4       arirang_good  278420  298050.0      효성첨단소재  ...   A+   A+    A   NaN
# ..               ...     ...       ...         ...  ...  ...  ...  ...   ...
# 199        navigator  580013  361610.0  SK아이이테크놀로지  ...  NaN  NaN  NaN   NaN
# 200  tiger_universal  289250   35250.0        강원랜드  ...    B    A    A   NaN
# 201  tiger_universal  289250   78930.0          GS  ...    C    A    A   BBB
# 202  tiger_universal  289250   42660.0      대우조선해양  ...   B+    B    A   CCC
# 203         kodex200  337160  180640.0         한진칼  ...    B    B    A   NaN
#
# [204 rows x 15 columns]

# %%
fig = px.scatter(esg_etf, x="ESG등급", y="시가총액")

fig.update_xaxes(categoryorder='array', categoryarray= ['D','C','B','B+','A','A+','S'])
fig.show()

# fig.update_layout(barmode='stack')
# fig.update_xaxes(categoryorder='array', categoryarray= ['d','a','c','b'])

fig = px.scatter(esg_etf, x="MSCI", y="시가총액")

fig.update_xaxes(categoryorder='array', categoryarray= ['CCC','B','BB','BBB','A','AA','AAA'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="797798be-741c-4a1a-88f8-46327a5be5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("797798be-741c-4a1a-88f8-46327a5be5cf")) {
#                     Plotly.newPlot(
#                         '797798be-741c-4a1a-88f8-46327a5be5cf',
# ...
